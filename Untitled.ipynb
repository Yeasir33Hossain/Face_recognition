# %%
# jupyter notebook


import os
import cv2
import numpy as np

os.chdir('C:/Users/zulka/Documents/Machine_Learning/face_recog(refreshed)')

faces = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    if len(faces) == 0: 
        return None
    
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 255), 2)
        cropped_face = img[y:y+h, x:x+w]
        return cropped_face  # Return the cropped face (exiting after finding the first one)

    return None

cap = cv2.VideoCapture(0)
count = 0

while True:
    ret, frame = cap.read()

    extracted_face = face_extractor(frame)  # Updated to avoid calling face_extractor multiple times

    if extracted_face is not None:
        count += 1
        
        # Resize the extracted face to a fixed size
        face = cv2.resize(extracted_face, (400, 400))
        
        # Save the extracted face to the specified directory
        file_name_path = "./training_data/Hasan_dark/" + str(count) + "dark" + ".jpg"
        cv2.imwrite(file_name_path, face)
        
        # Display the face count on the image
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 2)
        
        # Display the cropped face
        cv2.imshow("Face Cropper", face)  

    else:
        print("Face Not found")
        pass

    # Exit loop when 'Enter' (cv2.waitKey(1) == 13 refers to 'Enter' button) is pressed or after 100 faces are saved
    if cv2.waitKey(1) == 13 or count == 100:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Face Not found
# Face Not found
# Face Not found
# Face Not found
# Face Not found
# Face Not found
# Face Not found
# Face Not found
# Face Not found
# Face Not found

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, Lambda, Dense, Flatten, GlobalAveragePooling2D
from keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from glob import glob
from keras.layers import Dropout
import numpy as np
import matplotlib.pyplot as plt

# Set image size for input
IMAGE_SIZE = [224, 224]

# Define paths
train_path = 'training_data'
valid_path = 'testing_data'

# Load the InceptionV3 model without the top layers
inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# Freeze the pretrained layers
for layer in inception.layers:
    layer.trainable = False

# Get the number of output classes (3 classes: Person_1, Person_2, Unauthorized)
folders = glob('training_data/*')

# Add custom layers for your own classification task
x = inception.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)  # Adding dropout
prediction = Dense(len(folders), activation='softmax')(x)

# Create the model object
model = Model(inputs=inception.input, outputs=prediction)

# View the model summary
model.summary()

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Image augmentation for training data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=20,  # Adding rotation
    brightness_range=[0.8, 1.2],  # Adjusting brightness
    width_shift_range=0.2,  # Horizontal shift
    height_shift_range=0.2  # Vertical shift
)

training_set = train_datagen.flow_from_directory('training_data',
                                                 target_size=(224, 224),
                                                 batch_size=32,
                                                 class_mode='categorical')

# No augmentation for testing data, just rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

test_set = test_datagen.flow_from_directory('testing_data',
                                            target_size=(224, 224),
                                            batch_size=32,
                                            class_mode='categorical')

# Train the model
r = model.fit(
    training_set,
    validation_data=test_set,
    epochs=10,  # You can increase this for better results
    steps_per_epoch=len(training_set),
    validation_steps=len(test_set)
)

# Save the model
model.save('facefeatures_new_model_final.h5')
# Out:
# ...
# 60522496/87910968 ━━━━━━━━━━━━━━━━━━━━ 7:53 17us/step

# %%
from PIL import Image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import cv2
from keras.models import load_model
import numpy as np
import dlib
from imutils import face_utils
import imutils

# Load the trained model
model = load_model('facefeatures_new_model_final.h5')

# Load the face detection cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load dlib's face detector and facial landmarks predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

# Function for face alignment
def align_face(image, gray, rect):
    shape = predictor(gray, rect)
    shape = face_utils.shape_to_np(shape)

    # Extract left and right eye coordinates
    (lStart, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS["left_eye"]
    (rStart, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS["right_eye"]
    leftEyePts = shape[lStart:lEnd]
    rightEyePts = shape[rStart:rEnd]

    # Compute the center of mass for both eyes
    leftEyeCenter = leftEyePts.mean(axis=0).astype("int")
    rightEyeCenter = rightEyePts.mean(axis=0).astype("int")

    # Calculate the angle between the eye centroids
    dY = rightEyeCenter[1] - leftEyeCenter[1]
    dX = rightEyeCenter[0] - leftEyeCenter[0]
    angle = np.degrees(np.arctan2(dY, dX)) - 180

    # Compute the desired right eye x-coordinate based on the ratio
    desiredRightEyeX = 1.0 - 0.35

    # Compute the scaling factor
    dist = np.sqrt((dX ** 2) + (dY ** 2))
    desiredDist = (desiredRightEyeX - 0.35) * 224  # 224 is the target width
    scale = desiredDist / dist

    # Compute center between two eyes
    eyesCenter = ((leftEyeCenter[0] + rightEyeCenter[0]) // 2,
                  (leftEyeCenter[1] + rightEyeCenter[1]) // 2)

    # Get the rotation matrix for the desired eye angle
    M = cv2.getRotationMatrix2D(eyesCenter, angle, scale)

    # Perform the actual rotation and return the aligned face
    (w, h) = (224, 224)  # Input size for the model
    aligned_face = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC)
    
    return aligned_face

# Start video capture
video_capture = cv2.VideoCapture(0)
np.set_printoptions(suppress=True, precision=6)

while True:
    _, frame = video_capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect faces using dlib
    faces = detector(gray)
    
    # If more than 2 faces are detected, display "Unauthorized"
    if len(faces) > 2:
        cv2.putText(frame, "Unauthorized", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)
    else:
        # For each detected face, perform recognition
        for rect in faces:
            (x, y, w, h) = face_utils.rect_to_bb(rect)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 255), 2)

            # Align the face before resizing
            aligned_face = align_face(frame, gray, rect)
            
            # Resize face to the input size of the model
            face = cv2.resize(aligned_face, (224, 224))
            im = Image.fromarray(face, 'RGB')
            img_array = np.array(im)

            # Preprocess the image before feeding it to the model
            img_array = np.expand_dims(img_array, axis=0)
            img_array = preprocess_input(img_array)

            # Predict the class (person)
            pred = model.predict(img_array)
            print(pred)
            
            # List of names including the Unauthorized class
            names = ['Sifat', 'Hasan', 'Unauthorized']
            
            # Find the predicted class with the highest confidence
            index = np.argmax(pred[0])
            confidence = np.max(pred[0])
            
            # Set a threshold for authorized persons
            threshold = 0.8  # Increase the threshold for better distinction
            if confidence > threshold:
                name = names[index]
            else:
                name = 'Unauthorized'
            
            # Display the result on the frame
            cv2.putText(frame, name, (x, y-10), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 2)
    
    # Show the video frame
    cv2.imshow('Video', frame)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release video capture and close windows
video_capture.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# [[0. 1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# [[0.004336 0.995664]]
# ...
